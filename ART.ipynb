# %%
# import shutil
# shutil.rmtree("/content/adversarial-robustness-toolbox/")
# shutil.rmtree("/content/deepspeech.pytorch/")
# shutil.rmtree("/content/ARTToolbox/")

# %%
# !cd /content/

# %%
# !git clone https://github.com/Trusted-AI/adversarial-robustness-toolbox.git
# !cd adversarial-robustness-toolbox
# !pip install -e
# Out:
# Cloning into 'adversarial-robustness-toolbox'...
# remote: Enumerating objects: 75058, done.
# remote: Counting objects: 100% (707/707), done.
# remote: Compressing objects: 100% (280/280), done.
# remote: Total 75058 (delta 495), reused 590 (delta 425), pack-reused 74351
# Receiving objects: 100% (75058/75058), 398.70 MiB | 25.93 MiB/s, done.
# Resolving deltas: 100% (59402/59402), done.
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %% [markdown]
# STEP 1:  line 149 <class 'pytorch_lightning.core.module.LightningModule'>
#
# STEP 2: line 218 delete use_half
#
# STEP 3: line 384,458,569,628 outputs, output_sizes, *_ = self._model(inputs.to(self._device), input_sizes.to(self._device))
#
# Change file ImperceptableASR file:
#
# STEP 4: line 118 masker = PsychoacousticMasker()
#
# STEP 5: line 121 self.masker = masker

# %%
'''import ipywidgets as widgets
from IPython.display import display, HTML

my_string = ""

def on_button_clicked(b):
    global my_string
    if b.description == 'Colab':
        my_string = '/content/'
        other_button = button_kaggle
    else:
        my_string = '/kaggle/working/'
        other_button = button_colab
    print(my_string, "will be the path !")
    b.disabled = True
    other_button.disabled = True
    
button_colab = widgets.Button(description='Colab')
button_kaggle = widgets.Button(description='Kaggle')

button_colab.on_click(on_button_clicked)
button_kaggle.on_click(on_button_clicked)

display(widgets.HBox([button_colab, button_kaggle]))'''
# Out:
# 'import ipywidgets as widgets\nfrom IPython.display import display, HTML\n\nmy_string = ""\n\ndef on_button_clicked(b):\n    global my_string\n    if b.description == \'Colab\':\n        my_string = \'/content/\'\n        other_button = button_kaggle\n    else:\n        my_string = \'/kaggle/working/\'\n        other_button = button_colab\n    print(my_string, "will be the path !")\n    b.disabled = True\n    other_button.disabled = True\n    \nbutton_colab = widgets.Button(description=\'Colab\')\nbutton_kaggle = widgets.Button(description=\'Kaggle\')\n\nbutton_colab.on_click(on_button_clicked)\nbutton_kaggle.on_click(on_button_clicked)\n\ndisplay(widgets.HBox([button_colab, button_kaggle]))'

# %%
# !git config --global user.name "hammaad2002"
# !git config --global user.email "hammadalikhan2002@gmail.com"
# !git config --global user.password "6Xp5bq@WRDUuU2W"

# %%
token = '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' #this token will expire on Sat, Apr 8 2023
username = 'hammaad2002'
repo = 'ARTToolbox'

# %%
# !git config --global --unset http.proxy

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'ARTToolbox'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), 26.80 KiB | 5.36 MiB/s, done.

# %%
my_string = '/content/'

# %%
import os,shutil
os.remove(my_string + "adversarial-robustness-toolbox/art/attacks/evasion/imperceptible_asr/imperceptible_asr_pytorch.py")
shutil.copy(my_string + 'ARTToolbox/imperceptible_asr_pytorch.py', '/content/adversarial-robustness-toolbox/art/attacks/evasion/imperceptible_asr/')
os.remove(my_string + "adversarial-robustness-toolbox/art/estimators/speech_recognition/pytorch_deep_speech.py")
shutil.copy(my_string + 'ARTToolbox/pytorch_deep_speech.py','/content/adversarial-robustness-toolbox/art/estimators/speech_recognition/')
# Out:
# '/content/adversarial-robustness-toolbox/art/estimators/speech_recognition/pytorch_deep_speech.py'

# %%
'''!python --version
# !pip install --upgrade pip
# !pip install --upgrade "ipython<6"'''
# Out:
# '!python --version\n!pip install --upgrade pip\n!pip install --upgrade "ipython<6"'

# %%
# !git clone https://github.com/SeanNaren/deepspeech.pytorch.git && cd deepspeech.pytorch && python setup.py install
# Out:
# Cloning into 'deepspeech.pytorch'...
# remote: Enumerating objects: 1952, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 1952 (delta 74), reused 97 (delta 43), pack-reused 1805
# Receiving objects: 100% (1952/1952), 756.27 KiB | 7.64 MiB/s, done.
# Resolving deltas: 100% (1179/1179), done.
# running install
# running bdist_egg
# running egg_info
# creating deepspeech_pytorch.egg-info
# writing deepspeech_pytorch.egg-info/PKG-INFO
# writing dependency_links to deepspeech_pytorch.egg-info/dependency_links.txt
# writing top-level names to deepspeech_pytorch.egg-info/top_level.txt
# writing manifest file 'deepspeech_pytorch.egg-info/SOURCES.txt'
# reading manifest file 'deepspeech_pytorch.egg-info/SOURCES.txt'
# adding license file 'LICENCE'
# writing manifest file 'deepspeech_pytorch.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/decoder.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/checkpoint.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/__init__.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/training.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/enums.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/testing.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/inference.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/utils.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/validation.py -> build/lib/deepspeech_pytorch
# copying deepspeech_pytorch/model.py -> build/lib/deepspeech_pytorch
# creating build/lib/tests
# copying tests/__init__.py -> build/lib/tests
# copying tests/pretrained_smoke_test.py -> build/lib/tests
# copying tests/smoke_test.py -> build/lib/tests
# creating build/lib/deepspeech_pytorch/loader
# copying deepspeech_pytorch/loader/__init__.py -> build/lib/deepspeech_pytorch/loader
# copying deepspeech_pytorch/loader/data_loader.py -> build/lib/deepspeech_pytorch/loader
# copying deepspeech_pytorch/loader/spec_augment.py -> build/lib/deepspeech_pytorch/loader
# copying deepspeech_pytorch/loader/data_module.py -> build/lib/deepspeech_pytorch/loader
# copying deepspeech_pytorch/loader/sparse_image_warp.py -> build/lib/deepspeech_pytorch/loader
# creating build/lib/deepspeech_pytorch/data
# copying deepspeech_pytorch/data/__init__.py -> build/lib/deepspeech_pytorch/data
# copying deepspeech_pytorch/data/data_opts.py -> build/lib/deepspeech_pytorch/data
# copying deepspeech_pytorch/data/utils.py -> build/lib/deepspeech_pytorch/data
# creating build/lib/deepspeech_pytorch/configs
# copying deepspeech_pytorch/configs/__init__.py -> build/lib/deepspeech_pytorch/configs
# copying deepspeech_pytorch/configs/train_config.py -> build/lib/deepspeech_pytorch/configs
# copying deepspeech_pytorch/configs/lightning_config.py -> build/lib/deepspeech_pytorch/configs
# copying deepspeech_pytorch/configs/inference_config.py -> build/lib/deepspeech_pytorch/configs
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/decoder.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/checkpoint.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/__init__.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# creating build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/loader/__init__.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/loader/data_loader.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/loader/spec_augment.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/loader/data_module.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/loader/sparse_image_warp.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader
# copying build/lib/deepspeech_pytorch/training.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/enums.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# creating build/bdist.linux-x86_64/egg/deepspeech_pytorch/data
# copying build/lib/deepspeech_pytorch/data/__init__.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/data
# copying build/lib/deepspeech_pytorch/data/data_opts.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/data
# copying build/lib/deepspeech_pytorch/data/utils.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/data
# creating build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs
# copying build/lib/deepspeech_pytorch/configs/__init__.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs
# copying build/lib/deepspeech_pytorch/configs/train_config.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs
# copying build/lib/deepspeech_pytorch/configs/lightning_config.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs
# copying build/lib/deepspeech_pytorch/configs/inference_config.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs
# copying build/lib/deepspeech_pytorch/testing.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/inference.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/utils.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/validation.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# copying build/lib/deepspeech_pytorch/model.py -> build/bdist.linux-x86_64/egg/deepspeech_pytorch
# creating build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/__init__.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/pretrained_smoke_test.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/smoke_test.py -> build/bdist.linux-x86_64/egg/tests
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/decoder.py to decoder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/checkpoint.py to checkpoint.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader/data_loader.py to data_loader.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader/spec_augment.py to spec_augment.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader/data_module.py to data_module.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/loader/sparse_image_warp.py to sparse_image_warp.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/training.py to training.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/enums.py to enums.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/data/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/data/data_opts.py to data_opts.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/data/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs/train_config.py to train_config.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs/lightning_config.py to lightning_config.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/configs/inference_config.py to inference_config.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/testing.py to testing.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/inference.py to inference.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/validation.py to validation.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deepspeech_pytorch/model.py to model.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/pretrained_smoke_test.py to pretrained_smoke_test.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/smoke_test.py to smoke_test.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying deepspeech_pytorch.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deepspeech_pytorch.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deepspeech_pytorch.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deepspeech_pytorch.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deepspeech_pytorch.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/deepspeech_pytorch-0.1-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing deepspeech_pytorch-0.1-py3.9.egg
# removing '/usr/local/lib/python3.9/dist-packages/deepspeech_pytorch-0.1-py3.9.egg' (and everything under it)
# creating /usr/local/lib/python3.9/dist-packages/deepspeech_pytorch-0.1-py3.9.egg
# Extracting deepspeech_pytorch-0.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# deepspeech-pytorch 0.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.9/dist-packages/deepspeech_pytorch-0.1-py3.9.egg
# Processing dependencies for deepspeech-pytorch==0.1
# Finished processing dependencies for deepspeech-pytorch==0.1

# %%
if my_string == '/kaggle/working/':
    os.chdir('/kaggle/working/deepspeech.pytorch/')
else:
    os.chdir('/content/deepspeech.pytorch/')

# %%
# !cd /content/deepspeech.pytorch

# %%
import sys
sys.path.append(my_string + "deepspeech.pytorch")

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.9/dist-packages (1.9.4)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (1.13.1+cu116)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (23.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (0.8.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (0.11.4)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning) (2023.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.25.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.0)

# %%
# !pip install omegaconf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.9/dist-packages (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from omegaconf) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf) (6.0)

# %%
# !pip install python-levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-levenshtein in /usr/local/lib/python3.9/dist-packages (0.20.9)
# Requirement already satisfied: Levenshtein==0.20.9 in /usr/local/lib/python3.9/dist-packages (from python-levenshtein) (0.20.9)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from Levenshtein==0.20.9->python-levenshtein) (2.13.7)

# %%
# !pip install hydra-core --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.9/dist-packages (1.3.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.9/dist-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from hydra-core) (23.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0)

# %%
sys.path.append(my_string + "adversarial-robustness-toolbox")

# %%
# !git clone --recursive https://github.com/StickCui/warp-ctc-pytorch.git
# Out:
# Cloning into 'warp-ctc-pytorch'...
# remote: Enumerating objects: 41, done.
# remote: Total 41 (delta 0), reused 0 (delta 0), pack-reused 41
# Unpacking objects: 100% (41/41), 13.62 KiB | 1.13 MiB/s, done.
# Submodule 'warpctc/core' (https://github.com/baidu-research/warp-ctc) registered for path 'warpctc/core'
# Cloning into '/content/deepspeech.pytorch/warp-ctc-pytorch/warpctc/core'...
# remote: Enumerating objects: 497, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 497 (delta 11), reused 28 (delta 8), pack-reused 454
# Receiving objects: 100% (497/497), 366.18 KiB | 4.36 MiB/s, done.
# Resolving deltas: 100% (230/230), done.
# Submodule path 'warpctc/core': checked out '6d5b8fac130638862d97dc48ef43a8d7b5a503bb'

# %%
'''!cd /content/warp-ctc-pytorch/warpctc/
# !sh /content/warp-ctc-pytorch/make.sh install'''
# Out:
# '!cd /content/warp-ctc-pytorch/warpctc/\n!sh /content/warp-ctc-pytorch/make.sh install'

# %%
# !pip install omegaconf --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.9/dist-packages (2.3.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf) (6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from omegaconf) (4.9.3)

# %%
# !pip install git+https://github.com/pytorch/hydra-torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/pytorch/hydra-torch
#   Cloning https://github.com/pytorch/hydra-torch to /tmp/pip-req-build-098nczy1
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/hydra-torch /tmp/pip-req-build-098nczy1
#   Resolved https://github.com/pytorch/hydra-torch to commit 4f560245c32842696e6853efc29e1a2471148a42
#   Preparing metadata (setup.py) ... done
# Collecting hydra-configs-torch@ git+https://github.com/pytorch/hydra-torch/#subdirectory=hydra-configs-torch
#   Cloning https://github.com/pytorch/hydra-torch/ to /tmp/pip-install-pl_3lgmu/hydra-configs-torch_4c150c73b9654477b60b1aed8c5ead3f
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/hydra-torch/ /tmp/pip-install-pl_3lgmu/hydra-configs-torch_4c150c73b9654477b60b1aed8c5ead3f
#   Resolved https://github.com/pytorch/hydra-torch/ to commit 4f560245c32842696e6853efc29e1a2471148a42
#   Preparing metadata (setup.py) ... done
# Collecting hydra-configs-torchvision@ git+https://github.com/pytorch/hydra-torch/#subdirectory=hydra-configs-torchvision
#   Cloning https://github.com/pytorch/hydra-torch/ to /tmp/pip-install-pl_3lgmu/hydra-configs-torchvision_dd146bf0ab9b46e3b3bf2370ee85b4e1
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/hydra-torch/ /tmp/pip-install-pl_3lgmu/hydra-configs-torchvision_dd146bf0ab9b46e3b3bf2370ee85b4e1
#   Resolved https://github.com/pytorch/hydra-torch/ to commit 4f560245c32842696e6853efc29e1a2471148a42
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.9/dist-packages (from hydra-configs-torch@ git+https://github.com/pytorch/hydra-torch/#subdirectory=hydra-configs-torch->hydra-torch==0.9) (2.3.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf->hydra-configs-torch@ git+https://github.com/pytorch/hydra-torch/#subdirectory=hydra-configs-torch->hydra-torch==0.9) (6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from omegaconf->hydra-configs-torch@ git+https://github.com/pytorch/hydra-torch/#subdirectory=hydra-configs-torch->hydra-torch==0.9) (4.9.3)

# %%
# !pip install hydra-configs-pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hydra-configs-pytorch-lightning in /usr/local/lib/python3.9/dist-packages (0.1.0)

# %% [markdown]
# **ART TOOLBOX instructions:**
# When installling ART toolbox do the changes given below in the art/estimator/speech_recognition/pytorch_deepspeech file or else the code won't run. First install the toolbox then navigate through the files and make changes before running all the cell in top to bottom manner.

# %%
# !cd /content/

# %%
# !git clone -b main https://github.com/hammaad2002/CRDNN_Model.git
# Out:
# Cloning into 'CRDNN_Model'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 130 (delta 8), reused 9 (delta 2), pack-reused 106
# Receiving objects: 100% (130/130), 48.94 MiB | 23.73 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
class psycho:
    def __init__(self, window, hop, sr):
        self.window_size = window
        self.hop_size = hop
        self.sample_rate = sr

# %%
masker = psycho(0.032,0.01,16000)

# %% [markdown]
# generate(x: ndarray, y: Optional[ndarray] = None, **kwargs)→ ndarray

# %%
# !pip install sox #need to install this properly for ART toolbox
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sox in /usr/local/lib/python3.9/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from sox) (1.22.4)

# %%
import IPython.display as ipd

# %% [markdown]
# # **------ATTACK IMPLEMENTATION ON DEEPSPEECH MODEL USING ART TOOLBOX------**

# %% [markdown]
# # **----------------------ATTACK PREPROCESSING AND INITIALIZATION----------------------**

# %%
import torch
from art.estimators.speech_recognition import PyTorchDeepSpeech
from art.attacks.evasion import FastGradientMethod , BasicIterativeMethod, ProjectedGradientDescent, ImperceptibleASRPyTorch, CarliniWagnerASR
import numpy as np
import librosa

# %%
# Create an ART estimator for the ASR model
estimator = PyTorchDeepSpeech( pretrained_model = "librispeech" )
# Out:
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/migration/migration.py:195: PossibleUserWarning: You have multiple `ModelCheckpoint` callback states in this checkpoint, but we found state keys that would end up colliding with each other after an upgrade, which means we can't differentiate which of your checkpoint callbacks needs which states. At least one of your `ModelCheckpoint` callbacks will not be able to reload the state.
#   rank_zero_warn(
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.1.5 to v1.9.4. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../root/.art/data/librispeech_pretrained_v3.ckpt`

# %%
# Load some audio data for testing
x, sr = librosa.load( my_string + "/deepspeech.pytorch/" + "CRDNN_Model/AudioSamplesASR/spk1_snt1.wav" , sr=None )
y = np.array([ 'THE CHILD ALMOST HURT THE BIG DOG' ])
y = y.reshape( 1 , 1 )
print( y.shape )
x = torch.from_numpy( x )
x = x.unsqueeze( 0 ) 
x = x.numpy()
print( x.shape )
y1 =  np.array(['THE CHILD ALMOST HURT THE BIG DOG'])
print(y1.shape)
# Out:
# (1, 1)
# (1, 45920)
# (1,)

# %% [markdown]
# # **------------------------------FAST GRADIENT DESCENT ATTACK-----------------------------**

# %%
# Create an adversarial attack using ImperceptibleASR method
attack1 = FastGradientMethod(estimator=estimator, batch_size= 1, eps = 0.3, targeted= True, eps_step= 0.01, norm = 2)
# Generate an adversarial example from the original audio data
x_adv1 = attack1.generate(x=x, y=y)
# Out:
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.

# %%
# Compare the transcription of the original and adversarial audio data
y_pred1 = estimator.predict( x )
y_adv_pred1 = estimator.predict( x_adv1 )
print("Original transcription:    ", y_pred1 )
print("Adversarial transcription: ", y_adv_pred1 )
# Out:
# Original transcription:     ['THE CHILD ALMOST HURT THE SMALL DOG']
# Adversarial transcription:  ['THE CHILD ALMOST FLIRT TOR SMALL DOG']

# %% [markdown]
# **Clean Audio**

# %%
ipd.Audio(x, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Perturbed Audio**

# %%
ipd.Audio(x_adv1, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **-----------------------------BASIC ITERATIVE METHOD ATTACK-----------------------------**

# %%
# Create an adversarial attack using ImperceptibleASR method
attack2 = BasicIterativeMethod(estimator=estimator, batch_size= 1, eps = 0.3, targeted= True, eps_step= 0.01, max_iter= 10, verbose= True)
# Generate an adversarial example from the original audio data
x_adv2 = attack2.generate(x=x, y=y)
# Out:
# PGD - Iterations:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# Compare the transcription of the original and adversarial audio data
y_pred2 = estimator.predict( x )
y_adv_pred2 = estimator.predict( x_adv2 )
print("Original transcription:    ", y_pred2 )
print("Adversarial transcription: ", y_adv_pred2 )
# Out:
# Original transcription:     ['THE CHILD ALMOST HURT THE SMALL DOG']
# Adversarial transcription:  ['']

# %% [markdown]
# **Clean Audio**

# %%
ipd.Audio(x, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Perturbed Audio**

# %%
ipd.Audio(x_adv2, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **--------------------------PROJECTED GRADIENT DESCENT ATTACK-------------------------**

# %%
# Create an adversarial attack using ImperceptibleASR method estimator=estimator, batch_size= 1, eps = 0.3, targeted= True, eps_step= 0.01,
attack3 = ProjectedGradientDescent(estimator=estimator, batch_size= 1, eps = 0.3, targeted= True, eps_step= 0.01, max_iter= 10, verbose = True, norm = 2)
# Generate an adversarial example from the original audio data
x_adv3 = attack1.generate(x=x, y=y)

# %%
# Compare the transcription of the original and adversarial audio data
y_pred3 = estimator.predict( x )
y_adv_pred3 = estimator.predict( x_adv3 )
print("Original transcription:    ", y_pred3 )
print("Adversarial transcription: ", y_adv_pred3)
# Out:
# Original transcription:     ['THE CHILD ALMOST HURT THE SMALL DOG']
# Adversarial transcription:  ['THE CHILD ALMOST FLIRT TOR SMALL DOG']

# %% [markdown]
# **Clean Audio**

# %%
ipd.Audio(x, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Perturbed Audio**

# %%
ipd.Audio(x_adv3, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **--------------------------------CARLINI AND WAGNER ATTACK-------------------------------**

# %%
# Create an adversarial attack using ImperceptibleASR method
attack4 = CarliniWagnerASR(estimator=estimator, batch_size= 1, eps = 2.0, decrease_factor_eps = 10.0)
# Generate an adversarial example from the original audio data
x_adv4 = attack4.generate(x=x, y=y1)

# %%
# Compare the transcription of the original and adversarial audio data
y_pred4 = estimator.predict( x )
y_adv_pred4 = estimator.predict( x_adv4 )
print("Original transcription: ", y_pred4 )
print("Adversarial transcription: ", y_adv_pred4 )

# %% [markdown]
# **Clean Audio**

# %%
ipd.Audio(x, rate = sr)

# %% [markdown]
# **Perturbed Audio**

# %%
ipd.Audio(x_adv4, rate = sr)

# %% [markdown]
# # **---------------------------------IMPERCEPTIBLE ASR ATTACK--------------------------------**

# %% [markdown]
# # DOCUMENTATION OF IMPERCEPTABLE ASR ATTACK
#
# **ARGUMENTS:** estimator: SPEECH_RECOGNIZER_TYPE, masker: PsychoacousticMasker, eps: float = 2000.0, learning_rate_1: float = 100.0, max_iter_1: int = 1000, alpha: float = 0.05, learning_rate_2: float = 1.0, max_iter_2: int = 4000, loss_theta_min: float = 0.05, decrease_factor_eps: float = 0.8, num_iter_decrease_eps: int = 10, increase_factor_alpha: float = 1.2, num_iter_increase_alpha: int = 20, decrease_factor_alpha: float = 0.8, num_iter_decrease_alpha: int = 50, batch_size: int = 1)→ None¶
# Create an instance of the ImperceptibleASR.
#
# The default parameters assume that audio input is in int16 range. If using normalized audio input, parameters eps and learning_rate_{1,2} need to be scaled with a factor 2^-15
#
# Parameters
# :
# estimator – A trained speech recognition estimator.
#
# masker – A Psychoacoustic masker.
#
# eps (float) – Initial max norm bound for adversarial perturbation.
#
# learning_rate_1 (float) – Learning rate for stage 1 of attack.
#
# max_iter_1 (int) – Number of iterations for stage 1 of attack.
#
# alpha (float) – Initial alpha value for balancing stage 2 loss.
#
# learning_rate_2 (float) – Learning rate for stage 2 of attack.
#
# max_iter_2 (int) – Number of iterations for stage 2 of attack.
#
# loss_theta_min (float) – If imperceptible loss reaches minimum, stop early. Works best with batch_size=1.
#
# decrease_factor_eps (float) – Decrease factor for epsilon (Paper default: 0.8).
#
# num_iter_decrease_eps (int) – Iterations after which to decrease epsilon if attack succeeds (Paper default: 10).
#
# increase_factor_alpha (float) – Increase factor for alpha (Paper default: 1.2).
#
# num_iter_increase_alpha (int) – Iterations after which to increase alpha if attack succeeds (Paper default: 20).
#
# decrease_factor_alpha (float) – Decrease factor for alpha (Paper default: 0.8).
#
# num_iter_decrease_alpha (int) – Iterations after which to decrease alpha if attack fails (Paper default: 50).
#
# batch_size (int) – Batch size.

# %%
# Create an adversarial attack using ImperceptibleASR method
attack5 = ImperceptibleASRPyTorch(estimator=estimator, batch_size= 1, eps = 2.0)
# Generate an adversarial example from the original audio data
x_adv5 = attack5.generate(x=x, y=y1)

# %%
# Compare the transcription of the original and adversarial audio data
y_pred5 = estimator.predict( x )
y_adv_pred5 = estimator.predict( x_adv5 )
print("Original transcription:    ", y_pred5 )
print("Adversarial transcription: ", y_adv_pred5 )

# %% [markdown]
# **Clean Audio**

# %%
ipd.Audio(x, rate = sr)

# %% [markdown]
# **Perturbed Audio**

# %%
ipd.Audio(x_adv5, rate = sr)

# %% [markdown]
# # **----------------------------------------------------------------------------------------------------**

# %%
while True:
  pass
